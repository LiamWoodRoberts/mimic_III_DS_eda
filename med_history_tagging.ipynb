# %%
# Packages
import pandas as pd
import re
import spacy
from spacy import displacy

import numpy as np

# modules
from section_parse import run

# %%
title = "HISTORY OF PRESENT ILLNESS:"
title = "DISCHARGE SUMMARY:"
history_sections = run(title)
history_sections = [i for i in history_sections if i != "NOT FOUND"]

# %%
print(history_sections[0])
# Out:
# DISCHARGE SUMMARY:  Oxacillin
# 2 grams intravenously every four hours to be continued for
# the remainder of a five week course to complete a total of
# six weeks of antibiosis (given the patient's and the
# patient's family's insistence of avoidance of transesophageal
# echocardiogram), Protonix 40 mg by mouth once daily, Colace
# 100 mg by mouth twice a day, Zestril 2.5 mg by mouth once
# daily, Tums, vitamin D, Coumadin 3 mg by mouth daily at
# bedtime, Lopressor 12.5 mg by mouth twice a day (this is the
# dose which the patient's family insists upon, as it was
# evidently his outpatient dose).

# %% [markdown]
# ### Pre Trained Model

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
text = history_sections[0]
doc = nlp(text)
displacy.render(doc,style="ent",jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">DISCHARGE SUMMARY:  Oxacillin</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2 grams
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  intravenously
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     every four hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  to be continued for</br>the remainder of a
# ...

# %% [markdown]
# ## Medication Tagging

# %%
from get_tags import create_ent_df,get_entity_tags,show_ents

# %%
ent_df = create_ent_df()
entities = get_entity_tags(text,ent_df)
show_ents(text,entities)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">DISCHARGE SUMMARY:
# <mark class="entity" style="background: rgb(60,180,240); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Oxacillin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DRUG</span>
# </mark>
# </br>2 grams intravenously
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     every
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Frequency</span>
# </mark>
#  four
# ...

# %%
text = history_sections[2]
entities = get_entity_tags(text,ent_df)
show_ents(text,entities)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">DISCHARGE SUMMARY:  Ms.</br>[**Known lastname 19013**] felt dizzy while sitting up the day before</br>discharge.  Her hematocrit on the day before discharge.  Her</br>hematocrit was checked, which was found to be 27.6.  For this</br>hematocrit and symptoms she was transfused one
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     unit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">unit</span>
# </mark>
#  of packed</br>red blood cells.  Her hematocrit rose approximately to
# ...

# %%
ent_df[ent_df["Entity"]=="route"]
# Out:
#          Name Entity  in_text
# 0      j tube  route    False
# 1     ex-vivo  route    False
# 2          ed  route     True
# 3          sl  route     True
# 4          nu  route     True
# ..        ...    ...      ...
# 74         id  route    False
# 75  both ears  route    False
# 76         pl  route     True
# 77      po/ng  route    False
# 78    iv drip  route    False
#
# [79 rows x 3 columns]
